# %%
# %load_ext autoreload
# %autoreload 2
from earlySN import dataset
from earlySN import lightcurve

import matplotlib.pyplot as plt

SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rcParams["figure.autolayout"] = True
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
yao = dataset.Dataset(base_path = "/Users/christineye/earlySN/earlySN", default = "yao", bands = ['r', 'g'])

# %%
yao.load_from_saved('./demo/')
# Out:
# Loaded Hubble diagram parameters
# Loaded excess search results
# Loaded lightcurve fit parameters

# %%
yao.excess_search(verbose = False, save_path = './demo/')
# Out:
# Searching for excess in 89 supernovae
# /Users/christineye/earlySN/earlySN/lightcurve.py:745: RuntimeWarning: invalid value encountered in sqrt
#   var = np.sqrt(np.diagonal(cov))
# /Users/christineye/earlySN/earlySN/lightcurve.py:180: RuntimeWarning: invalid value encountered in sqrt
#   var = np.sqrt(np.diagonal(cov))
# /Users/christineye/earlySN/earlySN/lightcurve.py:681: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   fmt = 'o', alpha = alphas[j], marker = markers[j], color = band, label = '{}'.format(labels[j]), markersize = 6)
# /Users/christineye/earlySN/earlySN/lightcurve.py:727: RuntimeWarning: invalid value encountered in sqrt
#   except:

# %%
test.gold
# Out:
# ['ZTF18abaxlpi', 'ZTF18abcflnz', 'ZTF18abxxssh']

# %%
test.bronze
# Out:
# ['ZTF18aailmnv',
#  'ZTF18aasdted',
#  'ZTF18aaslhxt',
#  'ZTF18aavrwhu',
#  'ZTF18aayjvve',
#  'ZTF18aazsabq',
#  'ZTF18abckujg',
#  'ZTF18abcrxoj',
#  'ZTF18abeecwe',
#  'ZTF18abfgygp',
#  'ZTF18abimsyv',
#  'ZTF18abpaywm',
#  'ZTF18abpmmpo',
#  'ZTF18abrzeym',
#  'ZTF18absdgon',
#  'ZTF18abssuxz',
#  'ZTF18abucvbf']

# %%
yao.gold = ['ZTF18aayjvve',  'ZTF18abcflnz',
           'ZTF18abucvbf', 'ZTF18abxxssh', ]

yao.bronze = ['ZTF18aasdted', 'ZTF18abaxlpi', 'ZTF18abimsyv',
               'ZTF18abfgygp', 'ZTF18aaxsioa', 'ZTF18abssuxz', 'ZTF18abfhryc',
             'ZTF18aaslhxt', 'ZTF18aazsabq', 'ZTF18abauprj', ]

yao.gold_nd = ['ZTF18aavrzxp', 'ZTF18aazblzy', 'ZTF18abcysdx', 'ZTF18abetehf', 'ZTF18abxygvv']

# %%
ztf.gold = ['ZTF18aayjvve', 'ZTF18abauprj']
ztf.bronze = ['ZTF18abkhcwl', 'ZTF18abuhzfc', 'ZTF18abvejbm']
ztf.gold_nd = ['ZTF18aasprui', 'ZTF18abkhcrj']

# %%
test.excess = test.gold + test.bronze
test.nd = []

for i in test.sn_names:
    if i not in test.gold and i not in test.bronze:
        test.nd += [i]

# %%
test.N.loc['ZTF18aayjvve']['N'] = 8
test.N.loc['ZTF18abcflnz']['N'] = 9
test.N.loc['ZTF18abucvbf']['N'] = 8
test.N.loc['ZTF18abxxssh']['N'] = 10
test.N.loc['ZTF18aaslhxt']['N'] = 8
test.N.loc['ZTF18aasdted']['N'] = 8
test.N.loc['ZTF18aaxsioa']['N'] = 7
test.N.loc['ZTF18aazsabq']['N'] = 8
test.N.loc['ZTF18abaxlpi']['N'] = 9
test.N.loc['ZTF18abauprj']['N'] = 9
test.N.loc['ZTF18abimsyv']['N'] = 9
test.N.loc['ZTF18abfgygp']['N'] = 9
test.N.loc['ZTF18abfhryc']['N'] = 11
test.N.loc['ZTF18abssuxz']['N'] = 4

# %%
yao.fit_single_sn('ZTF18aaslhxt', cut = 10)
