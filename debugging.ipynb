# %%
# %load_ext autoreload
# %autoreload 2
from earlySN import dataset
from earlySN import lightcurve

import matplotlib.pyplot as plt

SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 20

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rcParams["figure.autolayout"] = True
# Out:
# Configuration file not found:
#
#     /Users/christineye/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.

# %%
yao = dataset.Dataset(base_path = "/Users/christineye/earlySN/earlySN", default = "yao", bands = ['r', 'g'])

# %%
yao.load_from_saved('./demo/')
# Out:
# Loaded Hubble diagram parameters
# Loaded excess search results
# Loaded lightcurve fit parameters

# %%
yao.excess_search(verbose = False, save_path = './demo/')
# Out:
# Searching for excess in 89 supernovae
# /Users/christineye/earlySN/earlySN/lightcurve.py:746: RuntimeWarning: invalid value encountered in sqrt
#   cov = np.linalg.inv(J.T.dot(J))
# /Users/christineye/earlySN/earlySN/lightcurve.py:184: RuntimeWarning: invalid value encountered in sqrt
#   cov = np.linalg.inv(J.T.dot(J))
# /Users/christineye/earlySN/earlySN/lightcurve.py:682: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   for j in range(len(binned_y[band])): # plot binned points
# /Users/christineye/earlySN/earlySN/lightcurve.py:728: RuntimeWarning: invalid value encountered in sqrt
#   cov = np.linalg.inv(J.T.dot(J))

# %%
yao.gold
# Out:
# ['ZTF18abaxlpi', 'ZTF18abcflnz', 'ZTF18abxxssh']

# %%
yao.bronze
# Out:
# ['ZTF18aailmnv',
#  'ZTF18aasdted',
#  'ZTF18aaslhxt',
#  'ZTF18aavrwhu',
#  'ZTF18aayjvve',
#  'ZTF18aazsabq',
#  'ZTF18abckujg',
#  'ZTF18abcrxoj',
#  'ZTF18abeecwe',
#  'ZTF18abfgygp',
#  'ZTF18abfhryc',
#  'ZTF18abimsyv',
#  'ZTF18abpaywm',
#  'ZTF18abpmmpo',
#  'ZTF18abrzeym',
#  'ZTF18absdgon',
#  'ZTF18abssuxz',
#  'ZTF18abucvbf']

# %%
yao.gold = ['ZTF18aayjvve',  'ZTF18abcflnz',
           'ZTF18abucvbf', 'ZTF18abxxssh', ]

yao.bronze = ['ZTF18aasdted', 'ZTF18abaxlpi', 'ZTF18abimsyv',
               'ZTF18abfgygp', 'ZTF18aaxsioa', 'ZTF18abssuxz', 'ZTF18abfhryc',
             'ZTF18aaslhxt', 'ZTF18aazsabq', 'ZTF18abauprj', ]

yao.gold_nd = ['ZTF18aavrzxp', 'ZTF18aazblzy', 'ZTF18abcysdx', 'ZTF18abetehf', 'ZTF18abxygvv']

# %%
yao.excess = yao.gold + yao.bronze
yao.nd = []

for i in yao.sn_names:
    if i not in yao.gold and i not in yao.bronze:
        yao.nd += [i]

# %%
ztf.gold = ['ZTF18aayjvve', 'ZTF18abauprj']
ztf.bronze = ['ZTF18abkhcwl', 'ZTF18abuhzfc', 'ZTF18abvejbm']
ztf.gold_nd = ['ZTF18aasprui', 'ZTF18abkhcrj']

# %%
test.excess = test.gold + test.bronze
test.nd = []

for i in test.sn_names:
    if i not in test.gold and i not in test.bronze:
        test.nd += [i]

# %%
yao.N.loc['ZTF18aayjvve']['N'] = 8
yao.N.loc['ZTF18abcflnz']['N'] = 9
yao.N.loc['ZTF18abucvbf']['N'] = 8
yao.N.loc['ZTF18abxxssh']['N'] = 10
yao.N.loc['ZTF18aaslhxt']['N'] = 8
yao.N.loc['ZTF18aasdted']['N'] = 8
yao.N.loc['ZTF18aaxsioa']['N'] = 7
yao.N.loc['ZTF18aazsabq']['N'] = 8
yao.N.loc['ZTF18abaxlpi']['N'] = 9
yao.N.loc['ZTF18abauprj']['N'] = 9
yao.N.loc['ZTF18abimsyv']['N'] = 9
yao.N.loc['ZTF18abfgygp']['N'] = 9
yao.N.loc['ZTF18abfhryc']['N'] = 11
yao.N.loc['ZTF18abssuxz']['N'] = 4

# %%
yao.fit_single_sn('ZTF18aaslhxt', cut = 10)

# %%
yao.compute_bump_properties()

# %%
yao.analyze_bump_amps('r', 'g')
# Out:
# r : 0.049424119936038936 0.003730181505990448
# g : 0.04496348429311966 0.005975153053976215
# $fr - fg = -0.004460635642919278 \pm 0.007043912839187781$
# $\log_{10}(g - r) = 0.09877730531565622 \pm 0.07297942143952438$

# %%
yao.analyze_bump_shapes()
# Out:
# $\mu$ 0.8174754993683119 0.29226804903115805
# $\sigma$ 0.7971218024927347 0.0794091419334663
